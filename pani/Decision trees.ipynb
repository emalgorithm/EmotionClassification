# %% [markdown]
# # Loading of data

# %%
import scipy.io
import math

mat = scipy.io.loadmat('../data/cleandata_students.mat')
x = mat['x'] # N examples each having 45 action unit features
N = len(x)   # Number of examples
y = mat['y'] # correct labels of N examples
attributes = ["AU" + str(i) for i in range(1, 46)]

# %% [markdown]
# # Node class

# %%
class Node(object):
    def __init__(self, kids=[], Class=None, op=None):
        self.kids = kids
        self.Class = Class # this might be a problem
        self.op = op

# %% [markdown]
# # Decision tree learning

# %%
def entropy(p, n):
    if (p == 0 or n == 0):
        return 0
    
    k0 = p / (p + n)
    k1 = n / (p + n)
    
    return - k0 * math.log2(k0) - k1 * math.log2(k1)

# %%
def all_elements_equal(l):
    for i in range(len(l)):
        if l[i] != l[0]:
            return False
    return True

def majority(l):
    total = 0
    for i in range(len(l)):
        if l[i] == 0:
            total -= 1
        else:
            total += 1
    if total < 0:
        return 0
    return 1


    
    

def choose_best_decision_attribute(examples, attributes, binary_attributes):
    # Choose attribute with highest information gain
    '''
    find p and n
    IG = entropy of inital examples
    for each attribute
        get subset of the data and find number of positive and negative examples
        IG -= 
    '''
    highest = 0  # ?
    total = len(binary_attributes)
    p = len([x for x in binary_attributes if x == 1])
    n = total - p
    
    IG = entropy(p, n)
    for attribute in range(len(attributes)):

        l = list(filter(lambda x: x[0][attribute] == 0, zip(examples, binary_attributes)))
        p0 = len([x for x in l if x[1] == 1])
        n0 = len([x for x in l if x[1] == 0])
        IG -= ((p0 + n0) / (p + n)) * entropy(p0, n0)
    
        l = list(filter(lambda x: x[0][attribute] == 1, zip(examples, binary_attributes)))
        p1 = len([x for x in l if x[1] == 1])
        n1 = len([x for x in l if x[1] == 0])
        IG -= ((p1 + n1) / (p + n)) * entropy(p1, n1)
        
    return highest

def decision_tree_learning(examples, attributes, binary_targets):
    if all_elements_equal(binary_targets):
        leaf = Node(Class=binary_targets[0])
        return leaf
    elif len(attributes) == 0:
        leaf = Node(Class=majority(binary_targets))
        return leaf

    best_attribute = choose_best_decision_attribute(examples, attributes, binary_targets)    
    root = Node(op=best_attribute)
    for value in range(0, 2): # for all possible values of attribute
        root.kids.append(Node())
        
        l = [x for x in zip(examples, binary_targets) if x[0][best_attribute] == value]
        examples_i, binary_targets_i = zip(*l)
        
        if len(examples_i) == 0:
            return Node(Class=majority(binary_targets))
        else:
            next_attributes = [x for x in attributes if x != best_attribute]
            return decision_tree_learning(examples_i, next_attributes, binary_targets_i)

    return root

# %% [markdown]
# # Construct all trees

# %%
# Emotions have labels 1 .. 6
trees = []
for i in range(1, 7):
    binary_targets = [i in example for example in y]
    trees.append(decision_tree_learning(x, attributes, binary_targets))
    
# We represent trees by their root node
print(trees)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/panayiotis/.local/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-98-d2c6f8013fad>", line 5, in <module>
#     trees.append(decision_tree_learning(x, attributes, binary_targets))
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 71, in decision_tree_learning
#     return decision_tree_learning(examples_i, next_attributes, binary_targets_i)
#   File "<ipython-input-97-0c69712d79a4>", line 59, in decision_tree_learning
#     best_attribute = choose_best_decision_attribute(examples, attributes, binary_targets)
#   File "<ipython-input-97-0c69712d79a4>", line 39, in choose_best_decision_attribute
#     l = list(filter(lambda x: x[0][attribute] == 0, zip(examples, binary_attributes)))
#   File "<ipython-input-97-0c69712d79a4>", line 39, in <lambda>
#     l = list(filter(lambda x: x[0][attribute] == 0, zip(examples, binary_attributes)))
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/panayiotis/.local/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 1828, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/panayiotis/.local/lib/python3.5/site-packages/IPython/core/ultratb.py", line 1090, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/panayiotis/.local/lib/python3.5/site-packages/IPython/core/ultratb.py", line 311, in wrapped
#     return f(*args, **kwargs)
#   File "/home/panayiotis/.local/lib/python3.5/site-packages/IPython/core/ultratb.py", line 345, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.5/inspect.py", line 1453, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.5/inspect.py", line 1414, in getframeinfo
#     lines, lnum = findsource(frame)
#   File "/home/panayiotis/.local/lib/python3.5/site-packages/IPython/core/ultratb.py", line 165, in findsource
#     file = getsourcefile(object) or getfile(object)
#   File "/usr/lib/python3.5/inspect.py", line 672, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/usr/lib/python3.5/inspect.py", line 709, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
# KeyboardInterrupt
# --------------------------------------------------------------------------
